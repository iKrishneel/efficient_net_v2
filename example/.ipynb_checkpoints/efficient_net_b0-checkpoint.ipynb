# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision as thv
from torchvision import transforms

from efficient_net.network import EfficientNetX as EfficientNet
from efficient_net.dataloader import create_loader
from efficient_net import model as m
from efficient_net.configs.optim_config import TrainConfig as Config

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
model = EfficientNet(m.efficient_net_b0)

p = torch.load('../logs/efnet_20200520120139/efficient_net.pt')
model.load_state_dict(p)

model.eval()
device = torch.device('cuda:0')
model = model.to(device)
# Out:
# Sequential(
#   (0): ConvBNA(
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   )
#   (1): MBConvX(
#     (conv_ip): ConvBNA(
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (activation): Swish()
#     )
#     (conv_dw): ConvBNA(
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (activation): Swish()
#     )
#     (conv_op): ConvBNA(
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (_sqex): SqueezeExcitation(
# ...

# %%
dataset = os.path.join(os.getcwd(), '../../../datasets/caltech256/256_ObjectCategories/')
assert os.path.isdir(dataset)

# %%
_, loader = create_loader(dataset)

transform = transforms.Compose(
            [transforms.CenterCrop(config.INPUT_SHAPE[1:]),
             transforms.ToTensor()])
loader.transform = transform

x = next(iter(loader))
im, label = x
im = im.detach().cpu().numpy().transpose((2, 1, 0))
print(im.shape)

plt.imshow(im)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b1202fa090ae> in <module>
#       2
#       3 transform = transforms.Compose(
# ----> 4             [transforms.CenterCrop(config.INPUT_SHAPE[1:]),
#       5              transforms.ToTensor()])
#       6 loader.transform = transform
#
# NameError: name 'config' is not defined

# %%
c = 0
i = 0
for image, label in loader:
    # image = image.detach().cpu().numpy()
    # image = (image - np.min(image)) / 1
    
    # image2 = torch.from_numpy(image).float().to(device)
    im = image.to(device).unsqueeze(0)
    
    p = model(im)
    im2 = image.detach().cpu().numpy().transpose((2, 1, 0))
    plt.imshow(im2)
    plt.show()
    
    p = p.detach().cpu().numpy()[0]
    print(p.shape)
    print(p[np.argmax(p)])
    if np.argmax(p) == label:
        c += 1
    print([np.argmax(p), label])
    
    i += 1
    if i == 30:
        break

print(f'Correct: {c/ len(loader)}')
# Out:
# (257,)
# 11.383327
# [211, 233]
# (257,)
# 9.953705
# [256, 233]
# (257,)
# 7.9989705
# [209, 233]
# (257,)
# 7.0224266
# [209, 233]
# (257,)
# 10.012702
# [256, 233]
# (257,)
# 11.074
# [209, 233]
# (257,)
# 13.818024
# [256, 233]
# (257,)
# 9.251395
# [233, 233]
# (257,)
# 5.6478934
# [20, 233]
# (257,)
# 7.370044
# [209, 233]
# (257,)
# 16.445227
# [256, 233]
# (257,)
# 7.449476
# [256, 233]
# (257,)
# 6.274669
# [175, 233]
# (257,)
# 7.146096
# [58, 233]
# (257,)
# 6.696946
# [256, 233]
# (257,)
# 5.107043
# [256, 233]
# (257,)
# 13.113533
# [36, 233]
# (257,)
# 10.218465
# [68, 233]
# (257,)
# 6.063211
# [250, 233]
# (257,)
# 8.3966465
# [233, 233]
# (257,)
# 3.7071817
# [3, 233]
# (257,)
# 11.309848
# [198, 233]
# (257,)
# 11.861227
# [209, 233]
# (257,)
# 5.7763734
# [233, 233]
# (257,)
# 7.903427
# [233, 233]
# (257,)
# 8.057687
# [209, 233]
# (257,)
# 5.3977966
# [58, 233]
# (257,)
# 10.251848
# [209, 233]
# (257,)
# 9.613469
# [233, 233]
# (257,)
# 6.030756
# [233, 233]
# ...
